# %% [markdown]
# ### `Simple Linear Regression`

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("Study Hour.csv")
df.tail(6)
# Out:
#     Hours  Scores
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
plt.scatter(df['Hours'], df['Scores'])
plt.xlabel('Hours')
plt.ylabel('Scores')
# Out:
# Text(0, 0.5, 'Scores')

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     Hours
# 14    1.1
# 0     2.5
# 17    1.9
# 6     9.2
# 23    6.9

# %%
y_test
# Out:
# 14    17
# 0     21
# 17    24
# 6     88
# 23    76
# Name: Scores, dtype: int64

# %%
lr.predict(X_test.iloc[4].values.reshape(1,1))
# Out:
# d:\Software\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([70.09815497])

# %%
plt.scatter(df['Hours'], df['Scores'])
# plt.plot(X_test, lr.predict(X_test), color='red')
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %%
m = lr.coef_
m
# Out:
# array([9.94061514])

# %%
b = lr.intercept_
b
# Out:
# np.float64(1.5079104828268939)

# %%
# y = mx + b
y = m * 6.9 + b 
y
# Out:
# array([70.09815497])
