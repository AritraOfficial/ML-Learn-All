# %%
import numpy as np 
import pandas as pd 
from sklearn.datasets import make_regression
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# #### Create the data by own

# %%
X, y = make_regression(n_samples = 100, n_features=2, n_informative=2, n_targets=1, noise=20)

# %%
df = pd.DataFrame({
    'Feature 1': X[:, 0],
    'Feature 2': X[:, 1],
    'Target': y
})

# %%
df.head()
# Out:
#    Feature 1  Feature 2     Target
# 0   0.676901   0.723372  81.819013
# 1  -1.146730  -0.155844 -61.997047
# 2  -1.328808   1.680982 -12.964073
# 3   0.692638  -0.444314  64.141694
# 4   0.027118   0.775726  72.791635

# %%
fig = px.scatter_3d(df, x='Feature 1', y='Feature 2', z='Target', title='3D Scatter Plot of Features and Target')
fig.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
print("MAE >> ", mean_absolute_error(y_test, y_pred))
print("MSE >> ", mean_squared_error(y_test, y_pred))
print("R2 >> ", r2_score(y_test, y_pred))
# Out:
# MAE >>  16.289463088406887
# MSE >>  390.21581262190773
# R2 >>  0.9314482053373223

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(x, y)
z_final = model.predict(np.c_[xGrid.ravel(), yGrid.ravel()]).reshape(10,10)
z = z_final

final = np.vstack((xGrid.ravel().reshape(1,100), yGrid.ravel().reshape(1,100))).T

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = px.scatter_3d(df, x='Feature 1', y='Feature 2', z='Target', title='3D Scatter Plot of Features and Target')
fig.add_trace(go.Surface(z=z, x=xGrid, y=yGrid, colorscale='Viridis'))
fig.show()

# %%
model.coef_, model.intercept_
# Out:
# (array([61.75157081, 51.64059248]), np.float64(2.87335326361987))
